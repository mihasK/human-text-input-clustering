# %%
import pandas as pd
from icecream import ic

# %%
df = pd.read_csv('data/data_57.csv', index_col=0)
df = df[~df.text_input.isnull()]
df['true_cluster'] = df.cluster.copy()
df.head()
# Out:
#          id text_input cluster true_cluster
# 5  90663250          ?     NaN          NaN
# 6  90683982          ?     NaN          NaN
# 7  90669451          ?     NaN          NaN
# 8  90662341          ?     NaN          NaN
# 9  90661642          ?     NaN          NaN

# %%
known_labels = {c for c in df.cluster.unique() if c is not np.nan}
known_labels
# Out:
# {'BUX',
#  'Bitpanda',
#  'Comdirect',
#  'Consorsbank',
#  'DKB',
#  'DeGiro',
#  'Finanzen.net Zero',
#  'Flatex',
#  'ING',
#  'Justtrade',
#  'Nextmarkets',
#  'Onvista',
#  'Robinhood',
#  'S-Broker',
#  'Scalable Capital',
#  'Smartbroker',
#  'Trade Republic',
#  'Trading 212',
#  'Vivid Money',
#  'eToro'}

# %% [markdown]
# # Propblems

# %% [markdown]
# * Fuzzy match false positive: brokers -> S-broker. We need to use the information that "brokers" is a common word, while S-broker is something unique?
#
# * 'DKB' vs 'dks' - why we need ratio instead of absolute distance
# * 'Vivid' vs 'Vivid Money' - both words are common (more or less), but in this context 'vivid' is specific
# * 'plus500' vs '500plus' - fuzzy diff will be huge

# %% [markdown]
# # Preprocessing

# %%
import unicodedata, string
import unidecode, re
from unidecode import unidecode

def rem_punctuation(x):
    return x.translate(str.maketrans('', '', string.punctuation))

def normalize(s):
#     return unicodedata.normalize('NFKD', s)
    return unidecode(s)

def rem_extra_spaces(s):
    s = re.sub('  +', ' ', s)
    s = re.sub('\n', ' ', s)
    s = re.sub('\t', ' ', s)
    return s

    
def preprocess(x):
    if not x:
        return None
    
    x = rem_punctuation(x)
    x = rem_extra_spaces(x)
    x = normalize(x)
    x = x.lower()
    x = x.strip()
    return x or None

preprocess('Dafür muss man sich auskennen',)
# Out:
# 'dafur muss man sich auskennen'

# %%
df['text_pro'] = df.text_input.apply(preprocess)
df = df[~df.text_pro.isnull()]
df
# Out:
#             id  text_input            cluster       true_cluster  \
# 17    90669113           0                NaN                NaN
# 18    90665568           0                NaN                NaN
# 19    90671351       0,000                NaN                NaN
# 20    90670294           2                NaN                NaN
# 21    90679455           3                NaN                NaN
# ...        ...         ...                ...                ...
# 1592  90666125  Weiß nicht                NaN                NaN
# 1593  90682704         xtb                NaN                NaN
# 1594  90676142        zero  Finanzen.net Zero  Finanzen.net Zero
# 1595  90684425      Zfugiv                NaN                NaN
# 1596  90665184         Zzz                NaN                NaN
#
#      found_clusters     text_pro
# 17             None            0
# 18             None            0
# 19             None         0000
# 20             None            2
# 21             None            3
# ...             ...          ...
# 1592           None  weiss nicht
# 1593           None          xtb
# 1594           None         zero
# 1595           None       zfugiv
# 1596           None          zzz
#
# [1575 rows x 6 columns]

# %%
known_labels = {
    preprocess(l):l
    for l in known_labels
}
known_labels
# Out:
# {'trading 212': 'Trading 212',
#  'onvista': 'Onvista',
#  'nextmarkets': 'Nextmarkets',
#  'consorsbank': 'Consorsbank',
#  'bux': 'BUX',
#  'finanzennet zero': 'Finanzen.net Zero',
#  'ing': 'ING',
#  'degiro': 'DeGiro',
#  'sbroker': 'S-Broker',
#  'dkb': 'DKB',
#  'vivid money': 'Vivid Money',
#  'trade republic': 'Trade Republic',
#  'smartbroker': 'Smartbroker',
#  'justtrade': 'Justtrade',
#  'scalable capital': 'Scalable Capital',
#  'etoro': 'eToro',
#  'bitpanda': 'Bitpanda',
#  'comdirect': 'Comdirect',
#  'robinhood': 'Robinhood',
#  'flatex': 'Flatex'}

# %% [markdown]
# # Fuzzy search - classification

# %%
extract('500plus', ['plus500',])
# Out:
# [('plus500', 57.14285714285714, 0)]

# %%
from rapidfuzz import fuzz
from rapidfuzz.process import extractOne, extract
# from tabulate import tabulate
# from textwrap import fill

def ffind(text, targets):
    r = extractOne(text, targets, 
                   scorer=fuzz.QRatio, 
                   score_cutoff=70)
    r2 = extractOne(text, targets, 
               scorer=fuzz.token_ratio, 
               score_cutoff=89)

    return r or r2


def ffind_get_label(text, targets):
    res = ffind(text, targets)
    if res:
        return res[0]
ffind_get_label('dkb', targets=known_labels.keys())
# Out:
# 'dkb'

# %%
df['found_clusters'] = df.text_pro.apply(
     lambda t: ffind_get_label(t, targets=known_labels)
)
df.found_clusters.dropna()
# Out:
# /var/folders/6r/ymffrb5j5m5fjp9sdqd_jmyr0000gn/T/ipykernel_33031/230979205.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['found_clusters'] = df.text_pro.apply(
# 99            Bitpanda
# 100           Bitpanda
# 101           Bitpanda
# 102           Bitpanda
# 103           Bitpanda
#              ...
# 1581    Trade Republic
# 1582    Trade Republic
# 1583       Trading 212
# 1584       Trading 212
# 1585    Trade Republic
# Name: found_clusters, Length: 445, dtype: object

# %%
confused_df = df[~df.true_cluster.isna()][
    df.found_clusters != df.true_cluster
]
confused_df.found_clusters.value_counts(dropna=False)
# Out:
# /var/folders/6r/ymffrb5j5m5fjp9sdqd_jmyr0000gn/T/ipykernel_33031/1731788960.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   confused_df = df[~df.true_cluster.isna()][
# found_clusters
# None    202
# Name: count, dtype: int64

# %%
confused_df[confused_df.found_clusters.isna()]
# Out:
#             id text_input            cluster       true_cluster  \
# 128   90684999    brokers           S-Broker           S-Broker
# 133   90670739    capital   Scalable Capital   Scalable Capital
# 134   90676823    Capital   Scalable Capital   Scalable Capital
# 202   90681005    consors        Consorsbank        Consorsbank
# 203   90675156    consors        Consorsbank        Consorsbank
# ...        ...        ...                ...                ...
# 1540  90668451   Scalable   Scalable Capital   Scalable Capital
# 1541  90662959   Scalable   Scalable Capital   Scalable Capital
# 1551  90678609   Scapable   Scalable Capital   Scalable Capital
# 1589  90675476      Vivid        Vivid Money        Vivid Money
# 1594  90676142       zero  Finanzen.net Zero  Finanzen.net Zero
#
#      found_clusters  text_pro
# 128            None   brokers
# 133            None   capital
# 134            None   capital
# 202            None   consors
# 203            None   consors
# ...             ...       ...
# 1540           None  scalable
# 1541           None  scalable
# 1551           None  scapable
# 1589           None     vivid
# 1594           None      zero
#
# [202 rows x 6 columns]

# %%
df.text_input.to_list()
# Out:
# ['?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '???????',
#  '/',
#  '.',
#  '...',
#  '.....',
#  '......',
#  '..........',
#  '0',
#  '0',
#  '0,000',
#  '2',
#  '3',
#  '4',
#  '500plus',
#  '56',
#  '7865r',
#  '8989',
#  'aaaaaaaaaaaaaaaaaaaaaa',
#  'Aktien',
#  'Aktien 24',
#  'Aktien Aktuell',
#  'Alisnz',
#  'All Börse',
#  'Allvest',
#  'amazon',
#  'amazon',
#  'Amazon',
#  'Amazon',
#  'Amazon',
#  'Amazon',
#  'an eine',
#  'an keine',
#  'an keine bestimmte zuerst',
#  'an nichts',
#  'App',
#  'Apple',
#  'Apple',
#  'Ativi',
#  'auch',
#  'AXA',
#  'bank',
#  'bank',
#  'Bank',
#  'Bank',
#  'Bank',
#  'Bank',
#  'Bank',
#  'Bank',
#  'Bank depot',
#  'banken',
#  'Banken',
#  'Banken',
#  'Banken',
#  'Bankinstitut',
#  'Bet',
#  'Bet',
#  'Bevestor',
#  'Bfnfkd',
#  'binance',
#  'binance',
#  'binance',
#  'Binance',
#  'Binance',
#  'Binance',
#  'Binance',
#  'Binance',
#  'Binance',
#  'Binance',
#  'Binance',
#  'Binance',
#  'Binance',
#  'Bing X',
#  'Bison',
#  'Bit',
#  'Bitcion',
#  'bitcoin',
#  'bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin.com',
#  'Bitcoins',
#  'Bitcoins',
#  'bitpanda',
#  'Bitpanda',
#  'Bitpanda',
#  'Bitpanda',
#  'Bitpanda',
#  'Bitpanda',
#  'Bitpanda',
#  'Bitpanda',
#  'BitPanda',
#  'bittoro',
#  'Blackrock',
#  'Blockchain',
#  'Blockchain',
#  'Bmw',
#  'BnB',
#  'börse',
#  'Börse',
#  'Börse',
#  'Börse',
#  'Börse',
#  'Börse',
#  'Börse',
#  'Börse',
#  'Börse',
#  'Börse',
#  'Börse',
#  'Börse',
#  'Börse Frankfurt',
#  'Börse Frankfurt',
#  'brokers',
#  'btcoin',
#  'BWM',
#  'Bybit',
#  'Cain',
#  'capital',
#  'Capital',
#  'Capital.com',
#  'Captrader',
#  'Change',
#  'CHech24',
#  'check24',
#  'chek 24',
#  'Clarke',
#  'CMC markets',
#  'Co',
#  'Coca cola',
#  'coinbase',
#  'coinbase',
#  'coinbase',
#  'Coinbase',
#  'Coinbase',
#  'Coinbase',
#  'Coinbase',
#  'Coinbase',
#  'Coinbase',
#  'Coinbase',
#  'Coinbase',
#  'Coinbase',
#  'Coinbase',
#  'Coinbase',
#  'CoinBase',
#  'Coinbase.com',
#  'comdiirect',
#  'comdirect',
#  'comdirect',
#  'comdirect',
#  'comdirect',
#  'comdirect',
#  'comdirect',
#  'comdirect',
#  'comdirect',
#  'comdirect',
#  'comdirect',
#  'comdirect',
#  'comdirect',
#  'Comdirect',
#  'Comdirect',
#  'Comdirect',
#  'Comdirect',
#  'Comdirect',
#  'Comdirect',
#  'Comdirect',
#  'Comdirect',
#  'Comdirect',
#  'Comdirect',
#  'Comdirect',
#  'Comdirect',
#  'Comdirect',
#  'Comdirect',
#  'comdirect.de',
#  'comdirekt',
#  'comdirekt',
#  'Comdirekt',
#  'Comdirekt',
#  'Comdirext',
#  'comerz',
#  'cominvest Fondas P',
#  'Commerzbank',
#  'Commerzbank',
#  'Commerzbank',
#  'Commerzbank',
#  'Commerzbank',
#  'Commerzbank',
#  'consors',
#  'consors',
#  'consors',
#  'consors',
#  'Consors',
#  'Consors',
#  'Consors',
#  'Consors',
#  'Consors',
#  'Consors',
#  'consorsbank',
#  'consorsbank',
#  'consorsbank',
#  'Consorsbank',
#  'Consorsbank',
#  'Consorsbank',
#  'Consorsbank',
#  'Consorsbank',
#  'Consorsbank',
#  'Consorsbank',
#  'Consorsbank',
#  'Consorsbank',
#  'Consorsbank',
#  'Consorsbank',
#  'cortalconsors',
#  'Cortal Consors',
#  'crxt',
#  'Crypto',
#  'crypto.com',
#  'Crypto.com',
#  'Dab',
#  'Dafür muss man sich auskennen',
#  'Dax',
#  'Dax',
#  'Dax',
#  'Dax',
#  'Dax',
#  'Dax',
#  'Dax',
#  'Dax',
#  'DAX',
#  'DAX',
#  'DAX dowjones',
#  'degiro',
#  'Degiro',
#  'Degiro',
#  'Degiro',
#  'deka',
#  'Deka',
#  'Deka',
#  'Deka',
#  'Deka',
#  'Deka',
#  'Deka',
#  'Deka',
#  'Deka',
#  'Deka',
#  'Deka',
#  'DEKA',
#  'Dekafonds',
#  'Deka Investment',
#  'Deka Investments',
#  'deutche bank',
#  'deutsche Bank',
#  'Deutsche bank',
#  'Deutsche Bank',
#  'Deutsche Bank',
#  'Deutsche Bank',
#  'Deutsche Bank',
#  'Deutsche Bank',
#  'Deutsche Bank',
#  'Deutsche Bank',
#  'Deutsche Bank',
#  'Deutsche Bank',
#  'Deutsche Bank',
#  'Deutscher Aktienmarkt',
#  'DEutsche vermögens Beratung',
#  'diba',
#  'Diba',
#  'Diba',
#  'dkb',
#  'Dkb',
#  'DKB',
#  'DKB',
#  'DKB',
#  'DKB',
#  'DKB Broker',
#  'Dks',
#  'Dvag',
#  'dws',
#  'Dws',
#  'DWS',
#  'eft tokens',
#  'eltoro',
#  'Eltoro',
#  'Eltoro',
#  'El Toro',
#  'EL Toro',
#  'eterro',
#  'etf',
#  'Etf24',
#  'Eth',
#  'Etoreo',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'etoro',
#  'e toro',
#  'e toro',
#  'e toro',
#  'eToro',
#  'eToro',
#  'eToro',
#  'eToro',
#  'eToro',
#  'eToro',
#  'eToro',
#  'eToro',
#  'eToro',
#  'eToro',
#  'eToro',
#  'eToro',
#  'eToro',
#  'eToro',
#  'eToro',
#  'eToro',
#  'Etoro',
#  'Etoro',
#  'Etoro',
#  'Etoro',
#  'Etoro',
#  'Etoro',
#  'Etoro',
#  'Etoro',
#  'Etoro',
#  'Etoro',
#  'Etoro',
#  'Etoro',
#  'Etoro',
#  'Etoro',
#  'Etoro',
#  'Etoro',
#  'Etoro',
#  'Etoro',
#  'Etoro',
#  'Etoro',
#  'Etoro',
#  'Etoro',
#  'Etoro',
#  'Etoro',
#  'Etoro',
#  'Etoro',
#  'E toro',
#  'E toro',
#  'EToro',
#  'EToro',
#  'e torro',
#  'eTorro',
#  'Etorro',
#  'Facebook',
#  'Faltex',
#  'Feedback',
#  'Fex',
#  'Fhj',
#  'Finanzennero',
#  'finanzen.net',
#  'finanzen.net',
#  'Finanzen.net',
#  'finanzen.net zero',
#  'finanzen.net zero',
#  'Finanzen.net Zero',
#  'Finanzenzero',
#  'Finanzen zero net',
#  'Fjnchj',
#  'flatex',
#  'flatex',
#  'flat ex',
#  'Flatex',
#  'Flatex',
#  'Flatex',
#  'Flatex',
#  'Flatex',
#  'Flatex',
#  'Flatex',
#  'Flatex',
#  'Flatex',
#  'Flatex',
#  'Flatex',
#  'Flatex',
#  'Flatex',
#  'Fond',
#  'FONDMAN',
#  'Forex',
#  'Forex',
#  'Forex',
#  'Frankfurt',
#  'Frankfurt Börse',
#  'Frankfurter Fond Bank',
#  'ftx',
#  'Ftx',
#  'Ftx trade',
#  'Games',
#  'gar keins',
#  'Gau',
#  'Geld verlieren',
#  'German Brokernet',
#  'Gibt keine',
#  'google',
#  'Google',
#  'Google',
#  'Google',
#  'Growny',
#  'gut',
#  'gut',
#  'Gut',
#  'Habe keine Ahnung',
#  'hamburger volksbank',
#  'Haspa',
#  'hausbank',
#  'Hausbank',
#  'Hausbank',
#  'Hausbank',
#  'hgjkjhggjh',
#  'hier',
#  'HuK',
#  'i0',
#  'ich kenn da keine',
#  'ich kenne keinen',
#  'Ich kenne keinen',
#  'Ich kenne noch keine',
#  'Ich kenn mich da nicht aus',
#  'Ich weis nicht',
#  'Ich weiß es nicht genau',
#  'ich weiss nicht',
#  'IC markets',
#  'Idk',
#  'Igenius',
#  'I love you and I miss you so much and I hope you',
#  'in der regel meine hausbank',
#  'ing',
#  'ing',
#  'ing',
#  'ing',
#  'ing',
#  'ing',
#  'ing',
#  'Ing',
#  'Ing',
#  'Ing',
#  'Ing',
#  'Ing',
#  'Ing',
#  'Ing',
#  'Ing',
#  'Ing',
#  'Ing',
#  'Ing',
#  'Ing',
#  'Ing',
#  'ING',
#  'ING',
#  'ING',
#  'ING',
#  'ING',
#  'ING',
#  'ING',
#  'ING',
#  'ING',
#  'ING',
#  'ING',
#  'ING',
#  'ING',
#  'ING',
#  'Ingba',
#  'Ing depot',
#  'Ing diba',
#  'IngDiba',
#  'IngDiba',
#  'Ing DiBa',
#  'Ing DiBa',
#  'ING Diba',
#  'ING Diba',
#  'Instagram',
#  'Intel',
#  'Investitionen',
#  'Investmentfonds',
#  'Investopedia',
#  'Investor',
#  'IQ Option',
#  'Itoro',
#  'JA',
#  'jhjhhj',
#  'Julian hosp',
#  'Just Etf',
#  'ka',
#  'k.a.',
#  'Ka',
#  'Ka',
#  'Kei e',
#  'keien',
#  'Kein Ahnung',
#  'Kein bestimmtes',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'Keine',
#  'keine Ahnung',
#  'keine Ahnung',
#  'keine Ahnung',
#  'keine Ahnung',
#  'keine Ahnung',
#  'Keine ahnung',
#  'Keine ahnung',
#  'Keine Ahnung',
#  'Keine Ahnung',
#  'Keine Ahnung',
#  'Keine Ahnung',
#  'Keine Ahnung',
#  'Keine Ahnung',
#  'Keine Ahnung',
#  'Keine Ahnung',
#  'Keine Ahnung',
#  'Keine Ahnung',
#  'Keine Ahnung',
#  'Keine Ahnung',
#  'Keine Ahnung',
#  'Keine Ahnung',
#  'Keine Angabe',
#  'Keine Angaben',
#  'keinen',
#  'keinen',
#  'keinen',
#  'keinen',
#  'Keinen',
#  'Keiner',
#  'Keiner',
#  'Keines',
#  'Keine, und das ist gut so',
#  'kenen',
#  'Kenne ich nicht',
#  'kenne keine',
#  'kenne keine',
#  'Kenne keine',
#  'Kenne keine',
#  'Kenne keine',
#  'Kenne keine',
#  'Kenne keine',
#  'Kenne Keine',
#  'kenne keinen',
#  'kenneKeinen',
#  'keone',
#  'kkl',
#  'Kp',
#  'kraken',
#  'Kraken',
#  'krypto',
#  'krypto',
#  'Krypto',
#  'Krypto',
#  'Lang & Schwarz',
#  'Libatex',
#  'Libertex',
#  'Libertex',
#  'Libertex',
#  'Libertex',
#  'Libertex',
#  'Lynx',
#  'maxblue',
#  'Meine Bank',
#  'Meine Bank',
#  'meine Hausbank',
#  'Mercedes',
#  'Meta',
#  'Metamask',
#  'Mil',
#  'Msci',
#  'MSCI World',
#  'Msic world',
#  'n26',
#  'Nachhaltigkeit',
#  'Nachhaltigkeit',
#  'Nasdaq',
#  'Nein',
#  'Nein',
#  'Neobroker',
#  'Netflix',
#  'nft',
#  'nft web',
#  'nhjjn',
#  'Nicht bekannt',
#  'nichts',
#  'Nichts',
#  'Nix',
#  'Nordstern',
#  'ntv',
#  'Offertoro',
#  'ok',
#  'onvista',
#  'onvista',
#  'Onvista',
#  'Onvista',
#  'Onvista',
#  'OnVista',
#  'otore',
#  'plus500',
#  'plus500',
#  'plus500',
#  'Plus500',
#  'Plus500',
#  'Plus500',
#  'Plus500',
#  'Plus500',
#  'Plus500',
#  'Plus500',
#  'Plus 500',
#  'Plus 500',
#  'Post',
#  'Postbank',
#  'Postbank',
#  'Postbank',
#  'ProRealTime Trading',
#  'Quirion',
#  'rdt fwedt gwetzgw',
#  'reliancecapitalltd',
#  'renta4',
#  'robinhood',
#  'robinhood',
#  'Robinhood',
#  'Roboforex',
#  'rrtzuji',
#  'Safemoon',
#  'SB Broker',
#  'sbrocker',
#  'Sbroker',
#  'Sbroker',
#  'Sbroker',
#  'SBroker',
#  'S Broker',
#  'S-Broker',
#  'S-Broker',
#  'Scaalable Capital',
#  'scalable',
#  'scalable',
#  'Scalable',
#  'Scalable',
#  'Scalable',
#  'Scalable',
#  'Scalable',
#  'Scalable',
#  'Scalable',
#  'Scalable',
#  'Scalable',
#  'Scalable',
#  'Scalable',
#  'Scalable',
#  'Scalable',
#  'scalable capital',
#  'Scalable capital',
#  'Scalable Capital',
#  'Scalable Capital',
#  'Scalable Capital',
#  'Scalable Capital',
#  'Scalable Capital',
#  'Scalable Captial',
#  'Scalable Free Broker',
#  'Scaleable',
#  'sehr gut',
#  'Sigma',
#  'Skalable',
#  'Smart',
#  'smartbroker',
#  'Smartbroker',
#  'Smartbroker',
#  'Smartbroker',
#  'Smartbroker',
#  'Smartbroker',
#  'Smartbroker',
#  'Smartbroker',
#  'Smartbroker',
#  'Smartphone',
#  'sparda bank',
#  'sparkasse',
#  'sparkasse',
#  'sparkasse',
#  'sparkasse',
#  'sparkasse',
#  'sparkasse',
#  'sparkasse',
#  'sparkasse',
#  'Sparkasse',
#  'Sparkasse',
#  'Sparkasse',
#  'Sparkasse',
#  'Sparkasse',
#  'Sparkasse',
#  'Sparkasse',
#  'Sparkasse',
#  'Sparkasse',
#  'Sparkasse',
#  'Sparkasse',
#  'Sparkasse',
#  'Sparkasse',
#  'Sparkasse',
#  'Sparkasse',
#  'Sparkasse',
#  'Sparkasse',
#  'Sparkasse',
#  'sparkassen broker',
#  'Sparkassen Broker',
#  'sparkassenfonds',
#  'Sport',
#  'Ssk',
#  'sskbroker',
#  'stoker',
#  'Storm',
#  'Stuttgarter',
#  'Super',
#  'Sweatcoin',
#  'Swissborg',
#  'targobank',
#  'Targobank',
#  'Taxfix',
#  'Templeton',
#  'Tesla',
#  'Tesla',
#  'teste',
#  'Tickmill',
#  'Tipico',
#  'Tko',
#  'Toro',
#  'Toro',
#  'Traba',
#  'Trada',
#  'Trade R',
#  'trade replubic',
#  'Traderepubkic',
#  'traderepublic',
#  'traderepublic',
#  'trade republic',
#  'trade republic',
#  'trade republic',
#  'tradeRepublic',
#  'trade Republic',
#  'Traderepublic',
#  'Traderepublic',
#  'Traderepublic',
#  'Traderepublic',
#  'Traderepublic',
#  'Traderepublic',
#  'Traderepublic',
#  'Traderepublic',
#  'Trade republic',
#  'Trade republic',
#  'Trade republic',
#  'Trade republic',
#  'Trade republic',
#  'Trade republic',
#  'Trade republic',
#  'Trade republic',
#  'Trade republic',
#  'Trade republic',
#  'Trade republic',
#  'Trade republic',
#  'Trade Republic',
#  'Trade Republic',
#  'Trade Republic',
#  'Trade Republic',
#  'Trade Republic',
#  'Trade Republic',
#  'Trade Republic',
#  'Trade Republic',
#  'Trade Republic',
#  'Trade Republic',
#  'Trade Republic',
#  'Trade Republic',
#  'Trade Republic',
#  'Trade Republic',
#  'Trade Republic',
#  'Trade Republic',
#  'Trade Republic',
#  'Trade Republic',
#  'Trade Republic',
#  'Trade Republic',
#  'Trade Republic',
#  'Trade Republic',
#  'Trade Republic',
#  'trade republik',
#  'tradeRepublik',
#  'Traderepublik',
#  'Traderepublik',
#  'Traderepublik',
#  'Traderepublik',
#  'Trade Republik',
#  'Trade Republik',
#  'Trade Republik',
#  'Trade Republik',
#  'Trade Republik',
#  'Traderepubloc',
#  'tradererpublic',
#  'Trader Republik',
#  'Traderupblic',
#  'Trading',
#  'Trading',
#  'Trading Republic',
#  'Traiding.com',
#  'Uggig',
#  'Unbekannt',
#  'Union invest',
#  'Union Invest',
#  'unioninvestment',
#  'Union Investment',
#  'Union Investment',
#  'Union Investment',
#  'Union Investment',
#  'Uphold',
#  'Vanguard',
#  'Vergessen',
#  'verivox',
#  'vh hjgvuitvuztivi',
#  'vista',
#  'Vivid',
#  'Vivid',
#  'volksbank',
#  'volksbank',
#  'Volksbank',
#  'Volksbank',
#  'Volksbank',
#  'Volksbank',
#  'Vorex',
#  'VR-Bank',
#  'VR Banken',
#  'VR-Banken',
#  'Vw',
#  'Wallstreet',
#  'Watex',
#  'weis nicht',
#  'weis nicht',
#  'weis nicht',
#  'weis nicht',
#  'weiß ich nicht',
#  'Weiß ich nicht',
#  'Weiß ich nicht',
#  'Weiß ich nicht',
#  'Weiß ich nicht',
#  'weiss nicht',
#  'weiß nicht',
#  'weiß nicht',
#  'weiß nicht',
#  'weiß nicht',
#  'weiß nicht',
#  'weiß nicht',
#  'weiß nicht',
#  'Weiß nicht',
#  'Weiß nicht',
#  'Weiß nicht',
#  'Weiß nicht',
#  'Weiß nicht',
#  'Weiß nicht',
#  'Weiß nicht',
#  'Weiß nicht.',
#  'weltsparen',
#  'Wirexx',
#  'wiss nicht',
#  'World trade Republik',
#  'X',
#  'xetra',
#  'xetra',
#  'xtb',
#  'xtb',
#  ...]

# %%
df.cluster.value_counts(dropna=False)
# Out:
# cluster
# NaN                  951
# eToro                133
# Trade Republic       109
# ING                   73
# Comdirect             64
# Scalable Capital      57
# Consorsbank           39
# Flatex                39
# Smartbroker           24
# DKB                   20
# S-Broker              19
# Finanzen.net Zero     18
# Bitpanda              14
# Onvista               11
# Robinhood              8
# Trading 212            5
# DeGiro                 4
# Vivid Money            4
# Justtrade              3
# BUX                    2
# Nextmarkets            1
# Name: count, dtype: int64

# %%
import json
json.dumps(df.text_input[df.text_input.notna()].tolist())
# Out:
# '["?", "?", "?", "?", "?", "???????", "/", ".", "...", ".....", "......", "..........", "0", "0", "0,000", "2", "3", "4", "500plus", "56", "7865r", "8989", "aaaaaaaaaaaaaaaaaaaaaa", "Aktien", "Aktien 24", "Aktien Aktuell", "Alisnz", "All B\\u00f6rse", "Allvest", "amazon", "amazon", "Amazon", "Amazon", "Amazon", "Amazon", "an eine", "an keine", "an keine bestimmte zuerst", "an nichts", "App", "Apple", "Apple", "Ativi", "auch", "AXA", "bank", "bank", "Bank", "Bank", "Bank", "Bank", "Bank", "Bank", "Bank depot", "banken", "Banken", "Banken", "Banken", "Bankinstitut", "Bet", "Bet", "Bevestor", "Bfnfkd", "binance", "binance", "binance", "Binance", "Binance", "Binance", "Binance", "Binance", "Binance", "Binance", "Binance", "Binance", "Binance", "Bing X", "Bison", "Bit", "Bitcion", "bitcoin", "bitcoin", "Bitcoin", "Bitcoin", "Bitcoin", "Bitcoin", "Bitcoin", "Bitcoin", "Bitcoin", "Bitcoin", "Bitcoin", "Bitcoin.com", "Bitcoins", "Bitcoins", "bitpanda", "Bitpanda", "Bitpanda", "Bitpanda", "Bitpanda", "Bitpanda", "Bitpanda", "Bitpanda", "BitPanda", "bittoro", "Blackrock", "Blockchain", "Blockchain", "Bmw", "BnB", "b\\u00f6rse", "B\\u00f6rse", "B\\u00f6rse", "B\\u00f6rse", "B\\u00f6rse", "B\\u00f6rse", "B\\u00f6rse", "B\\u00f6rse", "B\\u00f6rse", "B\\u00f6rse", "B\\u00f6rse", "B\\u00f6rse", "B\\u00f6rse Frankfurt", "B\\u00f6rse Frankfurt", "brokers", "btcoin", "BWM", "Bybit", "Cain", "capital", "Capital", "Capital.com", "Captrader", "Change", "CHech24", "check24", "chek 24", "Clarke", "CMC markets", "Co", "Coca cola", "coinbase", "coinbase", "coinbase", "Coinbase", "Coinbase", "Coinbase", "Coinbase", "Coinbase", "Coinbase", "Coinbase", "Coinbase", "Coinbase", "Coinbase", "Coinbase", "CoinBase", "Coinbase.com", "comdiirect", "comdirect", "comdirect", "comdirect", "comdirect", "comdirect", "comdirect", "comdirect", "comdirect", "comdirect", "comdirect", "comdirect", "comdirect", "Comdirect", "Comdirect", "Comdirect", "Comdirect", "Comdirect", "Comdirect", "Comdirect", "Comdirect", "Comdirect", "Comdirect", "Comdirect", "Comdirect", "Comdirect", "Comdirect", "comdirect.de", "comdirekt", "comdirekt", "Comdirekt", "Comdirekt", "Comdirext", "comerz", "cominvest Fondas P", "Commerzbank", "Commerzbank", "Commerzbank", "Commerzbank", "Commerzbank", "Commerzbank", "consors", "consors", "consors", "consors", "Consors", "Consors", "Consors", "Consors", "Consors", "Consors", "consorsbank", "consorsbank", "consorsbank", "Consorsbank", "Consorsbank", "Consorsbank", "Consorsbank", "Consorsbank", "Consorsbank", "Consorsbank", "Consorsbank", "Consorsbank", "Consorsbank", "Consorsbank", "cortalconsors", "Cortal Consors", "crxt", "Crypto", "crypto.com", "Crypto.com", "Dab", "Daf\\u00fcr muss man sich auskennen", "Dax", "Dax", "Dax", "Dax", "Dax", "Dax", "Dax", "Dax", "DAX", "DAX", "DAX dowjones", "degiro", "Degiro", "Degiro", "Degiro", "deka", "Deka", "Deka", "Deka", "Deka", "Deka", "Deka", "Deka", "Deka", "Deka", "Deka", "DEKA", "Dekafonds", "Deka Investment", "Deka Investments", "deutche bank", "deutsche Bank", "Deutsche bank", "Deutsche Bank", "Deutsche Bank", "Deutsche Bank", "Deutsche Bank", "Deutsche Bank", "Deutsche Bank", "Deutsche Bank", "Deutsche Bank", "Deutsche Bank", "Deutsche Bank", "Deutscher Aktienmarkt", "DEutsche verm\\u00f6gens Beratung", "diba", "Diba", "Diba", "dkb", "Dkb", "DKB", "DKB", "DKB", "DKB", "DKB Broker", "Dks", "Dvag", "dws", "Dws", "DWS", "eft tokens", "eltoro", "Eltoro", "Eltoro", "El Toro", "EL Toro", "eterro", "etf", "Etf24", "Eth", "Etoreo", "etoro", "etoro", "etoro", "etoro", "etoro", "etoro", "etoro", "etoro", "etoro", "etoro", "etoro", "etoro", "etoro", "etoro", "etoro", "etoro", "etoro", "etoro", "etoro", "etoro", "etoro", "etoro", "etoro", "etoro", "etoro", "etoro", "etoro", "etoro", "etoro", "etoro", "etoro", "etoro", "etoro", "etoro", "etoro", "e toro", "e toro", "e toro", "eToro", "eToro", "eToro", "eToro", "eToro", "eToro", "eToro", "eToro", "eToro", "eToro", "eToro", "eToro", "eToro", "eToro", "eToro", "eToro", ...

# %%
df.text_input.value_counts(dropna=False)
# Out:
# text_input
# keine              68
# Keine              44
# etoro              42
# Trade Republic     36
# Etoro              35
#                    ..
# Keine Angabe        1
# Kein bestimmtes     1
# Kein Ahnung         1
# keien               1
# Zzz                 1
# Name: count, Length: 632, dtype: int64

# %%
df.cluster.value_counts(dropna=False)
# Out:
# cluster
# NaN                  951
# eToro                133
# Trade Republic       109
# ING                   73
# Comdirect             64
# Scalable Capital      57
# Consorsbank           39
# Flatex                39
# Smartbroker           24
# DKB                   20
# S-Broker              19
# Finanzen.net Zero     18
# Bitpanda              14
# Onvista               11
# Robinhood              8
# Trading 212            5
# DeGiro                 4
# Vivid Money            4
# Justtrade              3
# BUX                    2
# Nextmarkets            1
# Name: count, dtype: int64

# %%
df[~df.cluster.notna()].to_csv('data/data_57_not_clustered.csv')
